# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

f = h5py.File('mbhb_cat_mojito_lite_processed_MT_rounding_fixed.hdf5')

print('\n'.join([f'{key}: {f['Binaries'][key][3]:.3e}' for key in f['Binaries']]))
# Out:
# ChirpMassSSBFrame: 2.089e+05
# Declination: 9.975e-01
# Eccentricity: 0.000e+00
# EstimatedSNR: 5.304e+02
# GW22FrequencySSBFrame: 1.137e-04
# GW22FrequencySourceFrame: 3.167e-04
# ID: 3.000e+00
# InclinationAngle: 1.746e+00
# LuminosityDistance: 1.388e+04
# MassRatio: 6.525e+00
# OrbitalFrequencySSBFrame: 5.683e-05
# OrbitalFrequencySourceFrame: 1.583e-04
# PhaseReferenceSourceFrame: -2.240e+00
# PolarisationAngle: 1.332e+00
# PrimaryMassSSBFrame: 6.624e+05
# PrimaryMassSourceFrame: 2.378e+05
# PrimarySpinCompX: 0.000e+00
# PrimarySpinCompY: 0.000e+00
# PrimarySpinCompZ: -4.551e-01
# PrimarySpinParameter: -4.551e-01
# Redshift: 1.786e+00
# RightAscension: 3.185e+00
# SecondaryMassSSBFrame: 1.015e+05
# SecondaryMassSourceFrame: 3.644e+04
# SecondarySpinCompX: 0.000e+00
# SecondarySpinCompY: -0.000e+00
# SecondarySpinCompZ: -8.225e-01
# SecondarySpinParameter: -8.225e-01
# TimeCoalescencePetersSSBFrame: 2.901e+07
# TimeCoalescencePetersSourceFrame: 1.041e+07
# ...
